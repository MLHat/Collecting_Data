# %% [markdown]
# Dataset:
# https://github.com/fivethirtyeight/data/tree/master/airline-safety
#
# I chose this dataset because my brother is trying to become a pilot and it inspired me.

# %%
import pandas as pd
import seaborn as sns
import os
from glob import glob
from collections import Counter
import nltk

# %%
Airlines = pd.read_csv("Airlines.txt", delimiter=',')
print(Airlines)
# Out:
#                        airline  avail_seat_km_per_week  incidents_85_99  \
# 0                   Aer Lingus               320906734                2
# 1                    Aeroflot*              1197672318               76
# 2        Aerolineas Argentinas               385803648                6
# 3                  Aeromexico*               596871813                3
# 4                   Air Canada              1865253802                2
# 5                   Air France              3004002661               14
# 6                   Air India*               869253552                2
# 7             Air New Zealand*               710174817                3
# 8             Alaska Airlines*               965346773                5
# 9                     Alitalia               698012498                7
# 10          All Nippon Airways              1841234177                3
# 11                   American*              5228357340               21
# ...

# %%
Airlines.head(10)
# Out:
#                  airline  avail_seat_km_per_week  incidents_85_99  \
# 0             Aer Lingus               320906734                2
# 1              Aeroflot*              1197672318               76
# 2  Aerolineas Argentinas               385803648                6
# 3            Aeromexico*               596871813                3
# 4             Air Canada              1865253802                2
# 5             Air France              3004002661               14
# 6             Air India*               869253552                2
# 7       Air New Zealand*               710174817                3
# 8       Alaska Airlines*               965346773                5
# 9               Alitalia               698012498                7
#
#    fatal_accidents_85_99  fatalities_85_99  incidents_00_14  \
# 0                      0                 0                0
# 1                     14               128                6
# ...

# %%
#See whether there have been more or less incidents within the two different timeframes

#Im using .head(10) because otherwise the data fills up my screen and makes it hard to navigate
#however the df is more there to support the plot

#Airlines[['airline', 'incidents_85_99', 'incidents_00_14']]
Airlines.head(10)[['airline', 'incidents_85_99', 'incidents_00_14']]
# Out:
#                  airline  incidents_85_99  incidents_00_14
# 0             Aer Lingus                2                0
# 1              Aeroflot*               76                6
# 2  Aerolineas Argentinas                6                1
# 3            Aeromexico*                3                5
# 4             Air Canada                2                2
# 5             Air France               14                6
# 6             Air India*                2                4
# 7       Air New Zealand*                3                5
# 8       Alaska Airlines*                5                5
# 9               Alitalia                7                4

# %%
ax = Airlines[['incidents_85_99', 'incidents_00_14']].plot()

# %%
#Same but for fatal incidents
Airlines.head(10)[['airline', 'fatal_accidents_85_99', 'fatal_accidents_00_14']]
# Out:
#                  airline  fatal_accidents_85_99  fatal_accidents_00_14
# 0             Aer Lingus                      0                      0
# 1              Aeroflot*                     14                      1
# 2  Aerolineas Argentinas                      0                      0
# 3            Aeromexico*                      1                      0
# 4             Air Canada                      0                      0
# 5             Air France                      4                      2
# 6             Air India*                      1                      1
# 7       Air New Zealand*                      0                      1
# 8       Alaska Airlines*                      0                      1
# 9               Alitalia                      2                      0

# %%
ax = Airlines[['fatal_accidents_85_99', 'fatal_accidents_00_14']].plot()

# %%
#Same but for fatalities
Airlines.head(10)[['airline', 'fatalities_85_99', 'fatalities_00_14']]
# Out:
#                  airline  fatalities_85_99  fatalities_00_14
# 0             Aer Lingus                 0                 0
# 1              Aeroflot*               128                88
# 2  Aerolineas Argentinas                 0                 0
# 3            Aeromexico*                64                 0
# 4             Air Canada                 0                 0
# 5             Air France                79               337
# 6             Air India*               329               158
# 7       Air New Zealand*                 0                 7
# 8       Alaska Airlines*                 0                88
# 9               Alitalia                50                 0

# %%
ax = Airlines[['fatalities_85_99', 'fatalities_00_14']].plot()
